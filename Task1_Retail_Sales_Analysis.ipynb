# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("retail_sales_100.csv")
df.columns = df.columns.str.strip().str.lower()
print("Columns:", df.columns)
category_sales = df.groupby("category")["sales_amount"].sum()
print("\nTop Selling Categories:\n", category_sales)
plt.figure()
category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()
region_sales = df.groupby("region")["sales_amount"].sum()
print("\nSales by Region:\n", region_sales)
plt.figure()
region_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()
monthly_sales = df.groupby("month")["sales_amount"].sum()
print("\nMonthly Sales Trend:\n", monthly_sales)
plt.figure()
monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()
print("\nTop Selling Category:", category_sales.idxmax())
print("Highest Revenue Region:", region_sales.idxmax())
print("Best Sales Month:", monthly_sales.idxmax())
# Out:
# Columns: Index(['order_id', 'region', 'category', 'sales_amount', 'profit', 'month'], dtype='object')
#
# Top Selling Categories:
#  category
# Furniture          127364
# Office Supplies     87405
# Technology          79596
# Name: sales_amount, dtype: int64
# Sales by Region:
#  region
# East     78029
# North    80448
# South    73102
# West     62786
# Name: sales_amount, dtype: int64
# Monthly Sales Trend:
#  month
# Apr    26362
# Aug    25854
# Dec    30625
# Feb    16599
# Jan    26196
# Jul     6031
# Jun    32015
# Mar    28127
# May    30384
# Nov    27456
# Oct    21910
# Sep    22806
# Name: sales_amount, dtype: int64
# Top Selling Category: Furniture
# Highest Revenue Region: North
# Best Sales Month: Jun
